# %%
import sys
plist = ['/Applications/NEURON/lib/python']
for pd in plist:
    if pd in sys.path:
        sys.path.remove(pd)
        
import matplotlib.pyplot as plt
import numpy as np

# %%
# curr = np.linspace(0.05,0.30,100)
# somadecay = [0.7676424080851891 ,
# 0.7594264652197966 ,
# 0.7521559541861877 ,
# 0.7456767953665405 ,
# 0.739866632284441 ,
# 0.7346270689721902 ,
# 0.7298780803283972 ,
# 0.7255539174323189 ,
# 0.7216000612532355 ,
# 0.7179709244043245 ,
# 0.7146280950630235 ,
# 0.7115389794873354 ,
# 0.7086757414239824 ,
# 0.7060144653191742 ,
# 0.7035344901079417 ,
# 0.7012178743486361 ,
# 0.6990489634540152 ,
# 0.6970140369846755 ,
# 0.6951010192426544 ,
# 0.6932992402974381 ,
# 0.691599237481628 ,
# 0.689992589581062 ,
# 0.6884717776057968 ,
# 0.6870300673008133 ,
# 0.6856614095374313 ,
# 0.6843603554898686 ,
# 0.6831219840990912 ,
# 0.681941839796952 ,
# 0.6808158788369539 ,
# 0.679740422875717 ,
# 0.6787121186879446 ,
# 0.6777279030901396 ,
# 0.6767849723043253 ,
# 0.6758807551199646 ,
# 0.6750128893161252 ,
# 0.6741792008912987 ,
# 0.6733776857186566 ,
# 0.6726064933028427 ,
# 0.6718639123629035 ,
# 0.6711483580064186 ,
# 0.6704583602938267 ,
# 0.6697925540204123 ,
# 0.6691496695674568 ,
# 0.6685285246944164 ,
# 0.6679280171611951 ,
# 0.6673471180843145 ,
# 0.6667848659432702 ,
# 0.6662403611641317 ,
# 0.665712761216606 ,
# 0.6652012761687395 ,
# 0.6647051646502504 ,
# 0.6642237301813592 ,
# 0.663756317829165 ,
# 0.663302311157986 ,
# 0.6628611294440039 ,
# 0.662432225127902 ,
# 0.6620150814821344 ,
# 0.6616092104720459 ,
# 0.6612141507923492 ,
# 0.6608294660624098 ,
# 0.6604547431655972 ,
# 0.6600895907194707 ,
# 0.6597336376649459 ,
# 0.6593865319638029 ,
# 0.6590479393949668 ,
# 0.6587175424409439 ,
# 0.6583950392566389 ,
# 0.6580801427135465 ,
# 0.657772579512979 ,
# 0.657472089362565 ,
# 0.6571784242108842 ,
# 0.6568913475354144 ,
# 0.6566106336796106 ,
# 0.6563360672351624 ,
# 0.6560674424658802 ,
# 0.655804562770002 ,
# 0.6555472401779466 ,
# 0.6552952948828367 ,
# 0.6550485548013141 ,
# 0.654806855162405 ,
# 0.6545700381223605 ,
# 0.6543379524035874 ,
# 0.6541104529559241 ,
# 0.6538874006386777 ,
# 0.6536686619219413 ,
# 0.6534541086058524 ,
# 0.6532436175565404 ,
# 0.6530370704576324 ,
# 0.65283435357624 ,
# 0.6526353575424697 ,
# 0.6524399771415449 ,
# 0.6522481111177043 ,
# 0.6520596619891269 ,
# 0.6518745358731309 ,
# 0.6516926423210265 ,
# 0.6515138941619771 ,
# 0.6513382073553178 ,
# 0.6511655008507958 ,
# 0.6509956964562429 ,
# 0.6508287187122196 ,]

# distalenddecay = [0.037522316099160666 ,
# 0.03836936611476938 ,
# 0.03911849744675631 ,
# 0.039782768526891506 ,
# 0.0403730410889356 ,
# 0.040898423929139775 ,
# 0.04136661320793883 ,
# 0.04178415638367993 ,
# 0.04215665905441303 ,
# 0.04248894861676218 ,
# 0.04278520490845681 ,
# 0.04304906535462969 ,
# 0.043283710242099344 ,
# 0.04349193237124042 ,
# 0.04367619432720508 ,
# 0.04383867586554588 ,
# 0.04398131334867959 ,
# 0.04410583274787044 ,
# 0.04421377740426262 ,
# 0.044306531495962774 ,
# 0.04438533996748707 ,
# 0.04445132552934455 ,
# 0.04450550321900337 ,
# 0.044548792922528946 ,
# 0.044582030183128916 ,
# 0.04460597556449773 ,
# 0.04462132278999165 ,
# 0.04462870584082627 ,
# 0.044628705165786875 ,
# 0.04462185312991155 ,
# 0.04460863880910476 ,
# 0.044589512220779316 ,
# 0.04456488806668841 ,
# 0.04453514905256509 ,
# 0.04450064883956662 ,
# 0.044461714674485196 ,
# 0.04441864973895065 ,
# 0.044371735252184144 ,
# 0.044321232357073276 ,
# 0.04426738381528938 ,
# 0.04421041553373027 ,
# 0.04415053794163316 ,
# 0.04408794723520741 ,
# 0.04402282650448429 ,
# 0.04395534675524607 ,
# 0.04388566783730405 ,
# 0.04381393928903507 ,
# 0.04374030110689125 ,
# 0.043664884447581695 ,
# 0.04358781226972308 ,
# 0.04350919992098521 ,
# 0.0434291556760758 ,
# 0.04334778123031458 ,
# 0.0432651721530299 ,
# 0.043181418304551585 ,
# 0.04309660422017084 ,
# 0.043010809464088445 ,
# 0.04292410895605464 ,
# 0.042836573273130195 ,
# 0.04274826892875347 ,
# 0.04265925863107805 ,
# 0.042569601522355935 ,
# 0.04247935340096607 ,
# 0.04238856692753606 ,
# 0.042297291816467734 ,
# 0.04220557501405413 ,
# 0.04211346086426669 ,
# 0.04202099126319179 ,
# 0.041928205803008885 ,
# 0.04183514190632151 ,
# 0.04174183495158234 ,
# 0.041648318390287556 ,
# 0.04155462385655863 ,
# 0.04146078126967795 ,
# 0.04136681893009255 ,
# 0.041272763609365416 ,
# 0.04117864063450472 ,
# 0.04108447396707464 ,
# 0.04099028627745387 ,
# 0.04089609901458017 ,
# 0.04080193247149326 ,
# 0.040707805846963326 ,
# 0.04061373730346898 ,
# 0.0405197440217717 ,
# 0.04042584225231081 ,
# 0.04033204736362986 ,
# 0.04023837388802682 ,
# 0.04014483556460871 ,
# 0.04005144537991638 ,
# 0.039958215606273426 ,
# 0.03986515783800349 ,
# 0.03977228302564853 ,
# 0.03967960150831141 ,
# 0.03958712304423858 ,
# 0.039494856839750465 ,
# 0.03940281157661753 ,
# 0.03931099543797812 ,
# 0.03921941613288135 ,
# 0.039128080919539336 ,
# 0.03903699662736232 ,]

# plt.figure(figsize=(10,10))
# plt.plot(curr,somadecay,label='soma injection')
# plt.plot(curr,distalenddecay,label='leaf dendrite distal end injection')
# plt.legend(fontsize = 14, frameon=False)
# plt.xlabel('Magnitude of injection current (nA)')
# plt.ylabel('Decay factor')
# plt.title('Injection current vs. Decay factor')
# plt.show()

level = [1,2,3,4,5,6,7]

somainject = [0.9187825703789476,
0.8117034599986894,
0.7378497769540932,
0.6919315139767827,
0.663791941498895,
0.646477197852586,
0.6357527102510587]

dendinject = [0.2815216572877106,
0.13286285900800565,
0.07316560420625379,
0.044370638396459605,
0.028858733961671674,
0.01976481703984934,
0.014061271833048778]


plt.figure(figsize=(10,10))
plt.plot(level,somainject,label='soma injection')
plt.plot(level,dendinject,label='leaf dendrite distal end injection')
plt.legend(fontsize = 14, frameon=False)
plt.title('Level vs. Decay factor')
plt.show()
